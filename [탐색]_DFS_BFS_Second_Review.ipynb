# %% [markdown]
# <a href="https://colab.research.google.com/github/Steve-YJ/Python-Algorithm/blob/main/%5B%ED%83%90%EC%83%89%5D_DFS_BFS_Second_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DFS/BFS
# * Review
# * Understand it & Implement it

# %% [markdown]
# # 사전 지식(Background Knowledge)
# ## 재귀 함수(recursive function)
# * 재귀 함수를 문제 풀이에서 사용할 때는 재귀 함수가 언제 끝나는지, 종료 조건을 꼭 명시해야 한다
# * 자칫 종료 조건을 명시하지 않으면 함수가 무한 호출될 수 있다.

# %%
# 5-4.py 재귀 함수 종료 예제

def recursive_function(i):
    # 100번 째 출력했을 때 종료되도록 조건 명시
    if i == 3:
        return 
    else:
        print(i, "번째 재귀 함수에서", i+1, "번째 함수를 호출합니다")
        recursive_function(i + 1)
        print(i, "번째 함수를 종료합니다")

# %%
recursive_function(1)
# Out:
# 1 번째 재귀 함수에서 2 번째 함수를 호출합니다
# 2 번째 재귀 함수에서 3 번째 함수를 호출합니다
# 2 번째 함수를 종료합니다
# 1 번째 함수를 종료합니다

# %%
def recursive_function(i):
    if i == 100:
        return
    else:
        print(i, "번째 재귀 함수에서", i+1, "번째 함수를 호출합니다")
        recursive_function(i + 1)
        print(i, "번째 재귀 함수를 종료합니다")

# %%
recursive_function(1)
# Out:
# 1 번째 재귀 함수에서 2 번째 함수를 호출합니다
# 2 번째 재귀 함수에서 3 번째 함수를 호출합니다
# 3 번째 재귀 함수에서 4 번째 함수를 호출합니다
# 4 번째 재귀 함수에서 5 번째 함수를 호출합니다
# 5 번째 재귀 함수에서 6 번째 함수를 호출합니다
# 6 번째 재귀 함수에서 7 번째 함수를 호출합니다
# 7 번째 재귀 함수에서 8 번째 함수를 호출합니다
# 8 번째 재귀 함수에서 9 번째 함수를 호출합니다
# 9 번째 재귀 함수에서 10 번째 함수를 호출합니다
# 10 번째 재귀 함수에서 11 번째 함수를 호출합니다
# 11 번째 재귀 함수에서 12 번째 함수를 호출합니다
# 12 번째 재귀 함수에서 13 번째 함수를 호출합니다
# 13 번째 재귀 함수에서 14 번째 함수를 호출합니다
# 14 번째 재귀 함수에서 15 번째 함수를 호출합니다
# 15 번째 재귀 함수에서 16 번째 함수를 호출합니다
# 16 번째 재귀 함수에서 17 번째 함수를 호출합니다
# 17 번째 재귀 함수에서 18 번째 함수를 호출합니다
# 18 번째 재귀 함수에서 19 번째 함수를 호출합니다
# 19 번째 재귀 함수에서 20 번째 함수를 호출합니다
# 20 번째 재귀 함수에서 21 번째 함수를 호출합니다
# 21 번째 재귀 함수에서 22 번째 함수를 호출합니다
# 22 번째 재귀 함수에서 23 번째 함수를 호출합니다
# 23 번째 재귀 함수에서 24 번째 함수를 호출합니다
# 24 번째 재귀 함수에서 25 번째 함수를 호출합니다
# 25 번째 재귀 함수에서 26 번째 함수를 호출합니다
# 26 번째 재귀 함수에서 27 번째 함수를 호출합니다
# 27 번째 재귀 함수에서 28 번째 함수를 호출합니다
# 28 번째 재귀 함수에서 29 번째 함수를 호출합니다
# 29 번째 재귀 함수에서 30 번째 함수를 호출합니다
# 30 번째 재귀 함수에서 31 번째 함수를 호출합니다
# 31 번째 재귀 함수에서 32 번째 함수를 호출합니다
# ...

# %% [markdown]
# * 재귀 함수(recursive function) 정리
#     * 컴퓨터 내부에서 재귀 함수의 수행은 `'스택 자료구조'`를 이용한다
#     * 함수를 계속 호출했을 때 가장 마지막에 호출된 함수가 먼저 수행을 끝내야 그 앞의 함수 호출이 종료되기 때문이다

# %%
# 5-5.py 2가지 방식으로 구현한 팩토리얼 예제

# 재귀적으로 구현한 n!
def recursive_factorial(n):
    # if n == 1:
    if n <= 1:
        return 1
    else:
        return n * recursive_factorial(n-1)

# %%
recursive_factorial(5)
# Out:
# 120

# %% [markdown]
# * 점화식
#     * 수학에서 점화식은 특정한 함수를 자신보다 더 작은 변수에 대한 함수와의 관계로 표현한 것을 의미한다
#     * 뒤에서'다이나믹 프로그래밍(8장)'을 배울 때 보다 잘 이해해보자

# %% [markdown]
# # 탐색 알고리즘 DFS/BFS

# %% [markdown]
# ## DFS
# * DFS는 탐색을 위해서 사용되는 탐색 알고리즘이다
# * 특정 경로로 탐색하다가 특정한 상황에서 최대한 깊숙이 들어가서 노드를 방문한 후, 다시 돌아가 다른 경로로 탐색하는 알고리즘이다
#
#
# ### DFS 동작 과정
# * 탐색의 시작 노드를 스택에 삽입하고 방문 처리 한다
# * 스택의 최상단 노드에 방문하지 않은 인접 노드가 있다면 그 인접 노드를 스택에 넣고 방문처리를 한다. 방문하지 않은 인접 노드가 없다면 스택세어 최상단 노드를 꺼낸다
#
# <br>
# * 여기서 방문 처리란, 스택에 한 번 삽입되어 처리된 노드가 다시 삽입되지 않게 체크하는 것을 의미한다.
# * 방문처리를 함으로써 각 노드를 한 번씩만 처리할 수 있다

# %% [markdown]
# ### DFS 구현
# * 깊이 우선 탐색 DFS를 어떻게 구현할 수 있을까?
# * DFS는 스택 자료구조에 기초한다는 점에서 구현이 간단하다
# * DFS는 스택 자료구조를 이용하기 떄문에 실제 구현은 재귀 함수를 이용했을 때 매우 간결하게 구현할 수 있다

# %%
# DFS 메서드 정의
graph =[
        [],
        [2, 3, 8],
        [1, 7],
        [1, 4, 5],
        [3, 5],
        [3, 4], 
        [7], 
        [2, 6, 8],
        [1, 7]
]
visited = [False] * 9

def dfs(graph, v, visited):
    visited[v] = True
    print(v, end=" ")
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %% [markdown]
# ## BFS
# * BFS(Breadth First Search)알고리즘은 '너비 우선 탐색'이라는 의미를 갖는다
# * 쉽게 말해 가까운 노드부터 탐색하는 알고리즘이다<br>
# (DFS가 특정한 경로에서 깊이 우선 탐색을 수행했다면 BFS는 가까운 노드부터 탐색한다)
# * DFS는 최대한 멀리 있는 노드를 우선으로 탐색하는 방식으로 동작한다 했는데, BFS는 그 반대다
#
# ### BFS의 구현
# * BFS 구현에서는 선입선출 방식인 큐 자료구조를 이용하는 것이 정석이다
# * 인접한 노드를 반복적으로 큐에 넣도록 알고리즘을 작성하면 자연스럽게 먼저 들어온 것이 먼저 나가게 되어, 가까운 노드부터 탐색을 진행하게 된다
#
# ### BFS의 동작 방식
# * 탐색의 시작 노드를 큐에 삽입하고 방문 처리 한다
# * 큐에서 노드를 꺼내 해당 노드의 인접 노드 중에서 방문하지 않은 노드를 모두 큐에 삽입한다
# * 2, 3번의 과정을 더 이상 수행할 수 없을 때 까지 반복한

# %%
from collections import deque

graph =[
        [],
        [2, 3, 8],
        [1, 7],
        [1, 4, 5],
        [3, 5],
        [3, 4], 
        [7], 
        [2, 6, 8],
        [1, 7]
]
visited = [False] * 9

def bfs(graph, start, visited):
    queue = deque([])
    queue.append(start)
    # 현재 노드를 방문 처리
    visited[start] = True

    while queue:  # 큐가 빌때까지 반복한다
        v = queue.popleft()
        print(v, end=' ')
        # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6

# %% [markdown]
# ## DFS/BFS 정리

# %% [markdown]
# * 코딩 테스트 중 2차원 배열에서의 탐색 문제를 만나면 그래프 형태로 바꿔서 생각하면 풀이 방법을 조금 더 쉽게 떠올릴 수 있다
# * 코딩 테스트에서 탐색 문제를 보면 그래프 형태로 표현한 다음 풀이법을 고민하도록 하자
# * 지금까지 배운 내용을 토대로 실전 문제를 풀어보자
