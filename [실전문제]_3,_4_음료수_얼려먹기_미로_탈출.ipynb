# %% [markdown]
# <a href="https://colab.research.google.com/github/Steve-YJ/Python-Algorithm/blob/main/%5B%EC%8B%A4%EC%A0%84%EB%AC%B8%EC%A0%9C%5D_3%2C_4_%EC%9D%8C%EB%A3%8C%EC%88%98_%EC%96%BC%EB%A0%A4%EB%A8%B9%EA%B8%B0_%EB%AF%B8%EB%A1%9C_%ED%83%88%EC%B6%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part2. 주요 알고리즘 이론과 실전 문제
# ## 실전문제 3. 음료수 얼려 먹기

# %%
from google.colab import drive

drive.mount('../content/drive')
# Out:
# Mounted at ../content/drive

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/취.코.테/Part2. 주요 알고리즘 이론과 실전 문제/Ch05. 탐색 알고리즘 DFS BFS
! ls

# %%
from IPython.display import Image
Image('./음료수 얼려먹기.png', width=600)

# %%
n, m = map(int, input().split())

# graph 생성
graph = []
for i in range(n):
  graph.append(list(map(int, input())))


# 상, 하, 좌, 우 탐색
# dx = [-1, 1, 0, 0]
# dy = [0, 0, -1, 1]

# dfs 탐색 시작!
def dfs(x, y):
  # 주어진 범위를 벗어나는 경우에는 즉시 종료
  if x <= -1 or y <=-1 or x >=n or y >=m:
    return False
  # 현재 노드를 아직 방문하지 않았다면
  if graph[x][y] == 0:
    # 해당 노드를 방문 처리
    graph[x][y] = 1
    # 상, 하, 좌, 우의 위치를 모두 재귀적으로 호출한다
    dfs(x-1, y)
    dfs(x+1, y)
    dfs(x, y-1)
    dfs(x, y+1)
    return True  # 탐색 후 return True
  return False

# 이제 모든 위치에 대해서 dfs를 수행
result = 0
for i in range(n):
  for j in range(m):
    # 현재 위치에서 DFS 수행
    if dfs(i, j) == True:
      result += 1

    
print("정답: ", result)
# Out:
# 4 5
# 00110
# 00011
# 11111
# 00000
# 정답:  3

# %% [markdown]
# ## 실전문제 4. 미로 탈출

# %%
from IPython.display import Image
Image('./미로찾기.png', width=600)

# %%
from collections import deque
# n과 m의 값을 입력받는다
n, m = map(int, input().split())

graph = []
for i in range(n):
    graph.append(list(map(int, input())))

# 이동할 네 방향 정의 (상, 하, 좌, 우)
dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]

# BFS 소스코드 구현
def bfs(x, y):
    # 큐(Queue) 구현을 위해 deque 라이브러리 사용
    queue = deque()
    queue.append((x, y))
    # 큐가 빌때까지 반복수행(큐의 값이 없을 때까지 반복헤준다)
    while queue:
        x, y = queue.popleft()
        # 현재 위치에서 네 방향으로 위치 확인
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            # 미로 찾기 공간을 벗어난 경우 무시한다
            if nx < 0 or ny < 0 or nx >=n or ny >=m:
                continue
            # 벽인 경우에도 무시한다
            if graph[nx][ny] == 0:
                continue
            if graph[nx][ny] == 1:
                graph[nx][ny] = graph[x][y] + 1
                queue.append((nx, ny))

    # 가장 오른쪽 아래까지의 최단 거리 반환
    return graph[n-1][m-1]

print(bfs(0, 0))
# Out:
# 5 6
# 101010
# 111111
# 000001
# 111111
# 111111
# 10

# %%
111
